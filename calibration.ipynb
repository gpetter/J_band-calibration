# %%
import calibration
calibration.extractSept()
calibration.extractOct()
calibration.extractionComment()
calibration.plotComment()
calibration.makeplot('oct')
calibration.removeNearObjs('oct')
calibration.apertureComment()
calibration.findAperture('oct')
calibration.matchoctseptcomment()
calibration.matchOctSept()
calibration.twomassmatchcomment()
calibration.twomassmatch()
calibration.calculateZP()
calibration.calculateoctmags()
calibration.makeplot('sept')
calibration.findAperture('sept')
calibration.calculateSeptMags()
# Out:
# /Users/graysonpetter/anaconda/envs/iraf27/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# First, Sextractor is run on September data. The pixel scale is given as 0.159 asec/pixel, and the FWHM is measured to be 4.9 pixels. Therefore the SEEING_FWHM is calculated to be 0.78 asec. This value along with the zeropoint estimate is used to configure Sextractor. The parameters retrieved are x and ycoordinates, flags, star class, RA & Dec, FWHM_Image, and fluxes from apertures of size 0.4'' to 6.6 '', counting by 0.2''
#
#  The same is done on October data, though RAs and Decs are excluded, andFWHM is taken to be 2.8, or 0.4452 arcsec. Catalogs are written to files for both October and September data.
#
# ...
